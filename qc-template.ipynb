# %%
import sys
import importlib
importlib.reload(utils)
import utils
import tszip

ts = tszip.decompress("data/hgdp_tgp_sgdp_chr6_q.dated.trees.tsz")
tinfo = utils.TreeInfo(ts, 6)
tinfo

# %%
tinfo.plot_polytomy_fractions(window_size=50_000, overlap=0)
